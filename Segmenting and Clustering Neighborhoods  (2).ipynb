# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
resp = requests.get(url)

# %%
resp.encoding = 'utf-8'    #轉換編碼至UTF-8
resp.encoding = 'big5'
resp.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(resp.text, 'lxml')

# %%
table = soup.find('table', {'class': 'wikitable sortable'})

# %%
columns = [th.text.replace('\n', '') for th in table.find('tr').find_all('th')]
columns
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %%
trs = table.find_all('tr')[1:]
rows = list()
for tr in trs:
    rows.append([td.text.replace('\n', '').replace('\xa0', '') for td in tr.find_all('td')])
rows[:5]
# Out:
# [['M1A', 'Not assigned', 'Not assigned'],
#  ['M2A', 'Not assigned', 'Not assigned'],
#  ['M3A', 'North York', 'Parkwoods'],
#  ['M4A', 'North York', 'Victoria Village'],
#  ['M5A', 'Downtown Toronto', 'Harbourfront']]

# %%
import pandas as pd
df = pd.DataFrame(data=rows, columns=columns)
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
df1 = df[~df['Borough'].isin(['Not assigned'])]
#df2=df1.groupby("Postcode").agg(lambda x:','.join(set(x)))
df2 = df1.groupby(['Postcode','Borough'], as_index=False).agg(lambda x: ','.join(x))

# %%
mask = df2['Neighbourhood'] == "Not assigned"
df2.loc[mask, 'Neighbourhood'] = df2.loc[mask, 'Borough']
df2.shape
# Out:
# (103, 3)

# %%
# !wget -O loan_train.csv http://cocl.us/Geospatial_data
# Out:
# --2020-03-12 08:17:44--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 158.85.108.86, 169.48.113.194, 158.85.108.83
# Connecting to cocl.us (cocl.us)|158.85.108.86|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2020-03-12 08:17:46--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|158.85.108.86|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-03-12 08:17:47--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 185.235.236.197
# Connecting to ibm.box.com (ibm.box.com)|185.235.236.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-03-12 08:17:47--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-03-12 08:17:47--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 185.235.236.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|185.235.236.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!6tsFsM-2fvyON_KJ0Kp0dkN6ea54IoyXWcXe7Ky55O_xNnAsv7v3E0yM6k7pbsS9hrnEx4u5bdQ8VsPHQWZiDZ9YrweKgwUc6NjoCPyJREOsAyoDle-BfK82Z8tDE9QycuNaZThGPYXnHcdKOzrMDqxh6f7BcDV6K5PM3Xh2GkzBIKOiEydPHBEO8ouM6jU651_B30T-zH00TLP_si0U5zj6QP9HGCZbBaY62rYLHKCUzJjBA7D8a-aqAbbIDLNll7nARO8HiZ7yczwVorAJfRR1Ga9ndrdzzt35PqZMscSt79pD5oCIR-4sCva7i8HyLfHGxOAoA_7eb5cvaP72dIOMt9ZIjnP69iRjgvnptXd9su1Xl3FWtOeRosLsxUwgjZkNYg4n_nU1-o0eU7uWdR0-I5xWlBHSW00_m9mFsBRCJ0-ulYdFIDEVgo9nQWkLadGAE-8DMxmqk8GsROWO6mXyHQMbrRqv62KdMMLOnYKQDEBCXR6XROrPlypHgjUCIa0ZrabrOet4pnMm2SsU9RQdtZmcj93_oSnupTfnRnFgJbm29tLRiTwFyVJDFDciZdXPMip9SPaDf4ZSueszKPQe87EAx7H618GGW-5vg_iH9dqJpN5Sfj9pJDL9u_2Q-ePFD67LtMBuqbFxSjOPAQD3zqoSfOl8RfwQX_KgxrJdXBcmRQZtkkc00429QnQAlyBFdJtkHkvnxBxXiFygNVLcxhCgIig5IlFAGgEA9Sq9MRPBt-lm7rGTb-zoOjzBzRnwCTIh2f-K5SRq8-el2-zqYpJwSczCgX-3A9Ip84xqySsmOSCNU07SqHyg9TBdFJ-g2t9wJRn68Ul-dpzZZSIJJ-euxf607YX7JZuP_iA0AV9V1yX98wGnw3fvS0r4gPUpPSS_IVFOUVnpJ5k4WQjeOzMTPS1cYXOSGu5XkdPXad4da0qmSyQ9hI6qO4MddVvu3U08ACLGLdxHhm20tLxr4Y4m0TNnBTsdjamKEtDrtucq05EBw_tRb9Wkd7jRFbzJtE8f5x6V5enV27nYDwnvRTrE-7sPn7HDf4wQh8p2xOCKyq4bsP09gkg45zudEWtghWRI_5eSpgQEWQDtXw-wtYiTf0Cd6mwbzIT7xO9XtMFBWc5AybGw4Cj-CWzjsYwa-2J5OjCE_9OK3kc0elp5s_LlL5VUgyKMj08mEZtRsi_HVA9vqrKZiHk9KPUkkwipwIflRsOVuSw4LoyMD5UICCPaAmjzZW4GR0O8ErqEW2TCmcg5-4n9JHyT1yh7wvncCSZWZ8smVlv-4yw-pohZbxOG5KGwtnCe2mD9_pbdU86aIousS2k8n3hP3pnfRckZ8zLW5jPZ7IUCEYf_gVdz3iXTvbNsXniezuYXuurNCH5sBCJDG3JnK8WEcg../download [following]
# --2020-03-12 08:17:48--  https://public.boxcloud.com/d/1/b1!6tsFsM-2fvyON_KJ0Kp0dkN6ea54IoyXWcXe7Ky55O_xNnAsv7v3E0yM6k7pbsS9hrnEx4u5bdQ8VsPHQWZiDZ9YrweKgwUc6NjoCPyJREOsAyoDle-BfK82Z8tDE9QycuNaZThGPYXnHcdKOzrMDqxh6f7BcDV6K5PM3Xh2GkzBIKOiEydPHBEO8ouM6jU651_B30T-zH00TLP_si0U5zj6QP9HGCZbBaY62rYLHKCUzJjBA7D8a-aqAbbIDLNll7nARO8HiZ7yczwVorAJfRR1Ga9ndrdzzt35PqZMscSt79pD5oCIR-4sCva7i8HyLfHGxOAoA_7eb5cvaP72dIOMt9ZIjnP69iRjgvnptXd9su1Xl3FWtOeRosLsxUwgjZkNYg4n_nU1-o0eU7uWdR0-I5xWlBHSW00_m9mFsBRCJ0-ulYdFIDEVgo9nQWkLadGAE-8DMxmqk8GsROWO6mXyHQMbrRqv62KdMMLOnYKQDEBCXR6XROrPlypHgjUCIa0ZrabrOet4pnMm2SsU9RQdtZmcj93_oSnupTfnRnFgJbm29tLRiTwFyVJDFDciZdXPMip9SPaDf4ZSueszKPQe87EAx7H618GGW-5vg_iH9dqJpN5Sfj9pJDL9u_2Q-ePFD67LtMBuqbFxSjOPAQD3zqoSfOl8RfwQX_KgxrJdXBcmRQZtkkc00429QnQAlyBFdJtkHkvnxBxXiFygNVLcxhCgIig5IlFAGgEA9Sq9MRPBt-lm7rGTb-zoOjzBzRnwCTIh2f-K5SRq8-el2-zqYpJwSczCgX-3A9Ip84xqySsmOSCNU07SqHyg9TBdFJ-g2t9wJRn68Ul-dpzZZSIJJ-euxf607YX7JZuP_iA0AV9V1yX98wGnw3fvS0r4gPUpPSS_IVFOUVnpJ5k4WQjeOzMTPS1cYXOSGu5XkdPXad4da0qmSyQ9hI6qO4MddVvu3U08ACLGLdxHhm20tLxr4Y4m0TNnBTsdjamKEtDrtucq05EBw_tRb9Wkd7jRFbzJtE8f5x6V5enV27nYDwnvRTrE-7sPn7HDf4wQh8p2xOCKyq4bsP09gkg45zudEWtghWRI_5eSpgQEWQDtXw-wtYiTf0Cd6mwbzIT7xO9XtMFBWc5AybGw4Cj-CWzjsYwa-2J5OjCE_9OK3kc0elp5s_LlL5VUgyKMj08mEZtRsi_HVA9vqrKZiHk9KPUkkwipwIflRsOVuSw4LoyMD5UICCPaAmjzZW4GR0O8ErqEW2TCmcg5-4n9JHyT1yh7wvncCSZWZ8smVlv-4yw-pohZbxOG5KGwtnCe2mD9_pbdU86aIousS2k8n3hP3pnfRckZ8zLW5jPZ7IUCEYf_gVdz3iXTvbNsXniezuYXuurNCH5sBCJDG3JnK8WEcg../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.25.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.25.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘loan_train.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2020-03-12 08:17:49 (303 MB/s) - ‘loan_train.csv’ saved [2891/2891]

# %%
dff = pd.read_csv('loan_train.csv')
dff.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
dff.rename(index=str, columns={"Postal Code": "Postcode"}, inplace = True)
neighborhood = pd.merge(df2, dff, on="Postcode", how='inner')

# %%
# !conda install folium -c conda-forge
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.10.1              |             py_0          59 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     branca:          0.4.0-py_0        conda-forge
#     folium:          0.10.1-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0     conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36h9f0ad1d_1 conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.10.1        | 59 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda list
# Out:
# # packages in environment at /opt/conda/envs/Python36:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _py-xgboost-mutex         2.0                       cpu_0
# absl-py                   0.7.0                    py36_0
# alabaster                 0.7.12                     py_0
# anaconda-client           1.7.2                    py36_0
# anaconda-project          0.8.2                    py36_0
# arcgis                    1.6.0            py36h39e3cac_1    esri
# arrow-cpp                 0.11.1           py36h5c3f529_1
# asn1crypto                0.24.0                   py36_0
# astor                     0.7.1                    py36_0
# astroid                   2.1.0                    py36_0
# astropy                   3.1.1            py36h7b6447c_0
# astunparse                1.6.2                     <pip>
# atomicwrites              1.3.0                    py36_1
# attrs                     18.2.0           py36h28b3542_0
# autoai-libs               1.10.5                    <pip>
# babel                     2.6.0                    py36_0
# backcall                  0.1.0                    py36_0
# backports                 1.0                        py_2
# backports.os              0.1.1                    py36_0
# backports.shutil_get_terminal_size 1.0.0                    py36_2
# beautifulsoup4            4.7.1                    py36_1
# biopython                 1.72             py36h04863e7_0
# bitarray                  0.8.3            py36h14c3975_0
# bkcharts                  0.2                      py36_0
# blas                      1.0                         mkl
# blaze                     0.11.3                   py36_0
# bleach                    3.1.0                      py_0
# blosc                     1.15.0               hd408876_0
# bokeh                     1.0.4                    py36_0
# boto                      2.49.0                   py36_0
# boto3                     1.9.82                     py_0
# botocore                  1.12.82                    py_0
# bottleneck                1.2.1            py36h035aef0_1
# branca                    0.4.0                      py_0    conda-forge
# brunel                    2.3                       <pip>
# bzip2                     1.0.7                h7b6447c_0
# c-ares                    1.15.0            h7b6447c_1001
# ca-certificates           2019.11.28           hecc5488_0    conda-forge
# cairo                     1.14.12              h8948797_3
# category-encoders         2.0.0                     <pip>
# certifi                   2019.11.28       py36h9f0ad1d_1    conda-forge
# cffi                      1.11.5           py36he75722e_1
# chardet                   3.0.4                 py36_1003
# click                     7.0                        py_0
# cloudpickle               0.7.0                      py_0
# clyent                    1.2.2                    py36_1
# colorama                  0.4.1                      py_0
# colour                    0.1.5                    py36_0
# contextlib2               0.5.5                    py36_0
# cplex                     12.9.0.0                  <pip>
# cryptography              2.5              py36h1ba5d50_0
# curl                      7.63.0            hbc83047_1000
# cx_oracle                 7.0.0            py36h7b6447c_0
# cycler                    0.10.0                   py36_0
# cython                    0.29.5           py36he6710b0_0
# cytoolz                   0.9.0.1          py36h14c3975_1
# dask                      1.1.1                      py_0
# dask-core                 1.1.1                      py_0
# datashape                 0.5.4                    py36_1
# dbus                      1.13.6               h746ee38_0
# decorator                 4.3.2                    py36_0
# defusedxml                0.5.0                    py36_1
# dill                      0.2.8.2                  py36_0
# distributed               1.25.3                   py36_0
# docloud                   1.0.375                   <pip>
# docplex                   2.12.182                  <pip>
# docutils                  0.14                     py36_0
# entrypoints               0.3                      py36_0
# et_xmlfile                1.0.1                    py36_0
# expat                     2.2.6                he6710b0_0
# fastcache                 1.0.2            py36h14c3975_2
# filelock                  3.0.10                   py36_0
# flask                     1.0.2                    py36_1
# flask-cors                3.0.7                    py36_0
# folium                    0.10.1                     py_0    conda-forge
# fontconfig                2.13.0               h9420a91_0
# freetds                   1.00.97              h1ba5d50_0
# freetype                  2.9.1                h8a8886c_1
# fribidi                   1.0.5                h7b6447c_0
# future                    0.17.1                   py36_0
# gast                      0.2.2                    py36_0
# geographiclib             1.49                      <pip>
# geojson                   2.4.1                     <pip>
# geopy                     1.18.1                    <pip>
# get_terminal_size         1.0.0                haa9412d_0
# gevent                    1.4.0            py36h7b6447c_0
# gflags                    2.2.2                he6710b0_0
# glib                      2.56.2               hd408876_0
# glob2                     0.6                      py36_1
# glog                      0.3.5                hf484d3e_1
# gmp                       6.1.2                h6c8ec71_1
# gmpy2                     2.0.8            py36h10f8cd9_2
# graphite2                 1.3.13               h23475e2_0
# graphviz                  2.40.1               h21bd128_2
# greenlet                  0.4.15           py36h7b6447c_0
# grpcio                    1.16.1           py36hf8bcb03_1
# gst-plugins-base          1.14.0               hbbd80ab_1
# gstreamer                 1.14.0               hb453b48_1
# h5py                      2.9.0            py36h7918eee_0
# harfbuzz                  1.8.8                hffaf4a1_0
# hdf5                      1.10.4               hb1b8bf9_0
# heapdict                  1.0.0                    py36_2
# html5lib                  1.0.1                      py_0
# ibm-bias-detection        1.0.8                     <pip>
# ibm-cos-sdk               2.4.3                     <pip>
# ibm-cos-sdk-core          2.4.3                     <pip>
# ibm-cos-sdk-s3transfer    2.4.3                     <pip>
# ibm-db                    2.0.9                     <pip>
# ibm-db-sa                 0.3.4                     <pip>
# ibmdbpy                   0.1.5                     <pip>
# icu                       58.2                 h9c2bf20_1
# idna                      2.8                      py36_0
# imageio                   2.4.1                    py36_0
# imagesize                 1.1.0                      py_0
# importlib_metadata        0.7                      py36_0
# intel-openmp              2019.1                      144
# ipykernel                 5.1.0            py36h39e3cac_0
# ipython                   7.2.0            py36h39e3cac_0
# ipython_genutils          0.2.0                    py36_0
# ipywidgets                7.4.2                    py36_0
# isort                     4.3.4                    py36_0
# itsdangerous              1.1.0                      py_0
# JayDeBeApi                1.1.1                     <pip>
# jbig                      2.1                  hdba287a_0
# jdcal                     1.4                      py36_0
# jedi                      0.13.2                   py36_0
# jeepney                   0.4                      py36_0
# jinja2                    2.10                     py36_0
# jmespath                  0.9.3                    py36_0
# jpeg                      9b                   h024ee3a_2
# JPype1                    0.6.3                     <pip>
# JPype1-py3                0.5.5.2                   <pip>
# jsonschema                2.6.0                    py36_0
# jupyter                   1.0.0                    py36_7
# jupyter-pip               0.3.1                     <pip>
# jupyter_client            5.2.4                    py36_0
# jupyter_console           6.0.0                    py36_0
# jupyter_core              4.4.0                    py36_0
# jupyterlab                0.35.3                   py36_0
# jupyterlab_server         0.2.0                    py36_0
# keras-applications        1.0.6                    py36_0
# keras-base                2.2.4                    py36_0
# keras-preprocessing       1.0.5                    py36_0
# keyring                   18.0.0                   py36_0
# kiwisolver                1.0.1            py36hf484d3e_0
# krb5                      1.16.1               h173b8e3_7
# lazy                      1.4                       <pip>
# lazy-object-proxy         1.3.1            py36h14c3975_2
# libarchive                3.3.3                h5d8350f_5
# libboost                  1.67.0               h46d08c1_4
# libcurl                   7.63.0            h20c2e04_1000
# libedit                   3.1.20181209         hc058e9b_0
# libevent                  2.1.8                h1ba5d50_0
# libffi                    3.2.1                hd88cf55_4
# libgcc-ng                 8.2.0                hdf63c60_1
# libgfortran-ng            7.3.0                hdf63c60_0
# liblief                   0.9.0                h7725739_2
# libpng                    1.6.37               hbc83047_0
# libpq                     11.1                 h20c2e04_0
# libprotobuf               3.6.1                hd408876_0
# libsodium                 1.0.16               h1bed415_0
# libssh2                   1.8.0                h1ba5d50_4
# libstdcxx-ng              8.2.0                hdf63c60_1
# libtiff                   4.1.0                h2733197_0
# libtool                   2.4.6                h7b6447c_5
# libuuid                   1.0.3                h1bed415_2
# libxcb                    1.13                 h1bed415_1
# libxgboost                0.80                 he6710b0_0
# libxml2                   2.9.9                hea5a465_1
# libxslt                   1.1.33               h7d1a2b0_0
# llvmlite                  0.27.0           py36hd408876_0
# locket                    0.2.0                    py36_1
# lomond                    0.3.3                     <pip>
# lxml                      4.3.1            py36hefd8a0e_0
# lz4-c                     1.8.1.2              h14c3975_0
# lzo                       2.10                 h49e0be7_2
# markdown                  3.0.1                    py36_0
# markupsafe                1.1.0            py36h7b6447c_0
# matplotlib                3.0.2            py36h5429711_0
# mccabe                    0.6.1                    py36_1
# mistune                   0.8.4            py36h7b6447c_0
# mkl                       2019.1                      144
# mkl-service               1.1.2            py36he904b0f_5
# mkl_fft                   1.0.10           py36ha843d7b_0
# mkl_random                1.0.2            py36hd81dba3_0
# mock                      2.0.0                    py36_0
# more-itertools            5.0.0                    py36_0
# mpc                       1.1.0                h10f8cd9_1
# mpfr                      4.0.1                hdf1c602_3
# mpld3                     0.3                      py36_0
# mpmath                    1.1.0                    py36_0
# msgpack-python            0.6.1            py36hfd86e86_1
# multipledispatch          0.6.0                    py36_0
# nbconvert                 5.4.0                    py36_1
# nbformat                  4.4.0                    py36_0
# ncurses                   6.1                  he6710b0_1
# networkx                  2.2                      py36_1
# nltk                      3.4                      py36_1
# nose                      1.3.7                    py36_2
# notebook                  5.7.8                    py36_0
# numba                     0.42.0           py36h962f231_0
# numexpr                   2.6.9            py36h9e4a6bb_0
# numpy                     1.15.4           py36h7e9f1db_0
# numpy-base                1.15.4           py36hde5b4d6_0
# numpydoc                  0.8.0                    py36_0
# odo                       0.5.1                    py36_0
# olefile                   0.46                       py_0
# openpyxl                  2.6.0                    py36_0
# openssl                   1.1.1d               h516909a_0    conda-forge
# packaging                 19.0                     py36_0
# pandas                    0.24.1           py36he6710b0_0
# pandoc                    1.19.2.1             hea2e7c5_1
# pandocfilters             1.4.2                    py36_1
# pango                     1.42.4               h049681c_0
# parso                     0.3.2                    py36_0
# partd                     0.3.9                    py36_0
# patchelf                  0.9                  he6710b0_3
# path.py                   11.5.0                   py36_0
# pathlib2                  2.3.3                    py36_0
# patsy                     0.5.1                    py36_0
# pbr                       5.1.3                      py_0
# pcre                      8.42                 h439df22_0
# pep8                      1.7.1                    py36_0
# pexpect                   4.6.0                    py36_0
# pickleshare               0.7.5                    py36_0
# pillow                    5.4.1            py36h34e0f95_0
# pip                       19.1.1                   py36_0
# pixiedust                 1.1.17                    <pip>
# pixman                    0.36.0               h7b6447c_0
# pkginfo                   1.5.0.1                  py36_0
# plotly                    3.6.1                    py36_0
# pluggy                    0.8.1                    py36_0
# ply                       3.11                     py36_0
# project-lib               1.7.1                     <pip>
# prometheus_client         0.5.0                    py36_0
# prompt_toolkit            2.0.8                      py_0
# protobuf                  3.6.1            py36he6710b0_0
# psutil                    5.5.0            py36h7b6447c_0
# psycopg2                  2.7.6.1          py36h1ba5d50_0
# ptyprocess                0.6.0                    py36_0
# py                        1.7.0                    py36_0
# py-lief                   0.9.0            py36h7725739_2
# py-xgboost                0.80             py36he6710b0_0
# pyarrow                   0.11.1           py36he6710b0_0
# pycodestyle               2.5.0                    py36_0
# pycosat                   0.6.3            py36h7b6447c_0
# pycparser                 2.19                       py_0
# pycrypto                  2.6.1            py36h14c3975_9
# pycurl                    7.43.0.2         py36h1ba5d50_0
# pyflakes                  2.1.0                    py36_0
# pygments                  2.3.1                    py36_0
# pylint                    2.2.2                    py36_0
# pymssql                   2.1.4            py36h7b6447c_0
# pyodbc                    4.0.25           py36he6710b0_0
# pyopenssl                 19.0.0                   py36_0
# pyparsing                 2.3.1                    py36_0
# pypyodbc                  1.3.4                     <pip>
# pyqt                      5.9.2            py36h05f1152_2
# pyshp                     2.1.0                      py_0
# pysocks                   1.6.8                    py36_0
# pytables                  3.4.4            py36h71ec239_0
# pytest                    4.2.1                    py36_0
# pytest-arraydiff          0.3              py36h39e3cac_0
# pytest-astropy            0.5.0                    py36_0
# pytest-doctestplus        0.2.0                    py36_0
# pytest-openfiles          0.3.2                    py36_0
# pytest-remotedata         0.3.1                    py36_0
# python                    3.6.9                h265db76_0
# python-dateutil           2.7.5                    py36_0
# python-libarchive-c       2.8                     py36_13
# python_abi                3.6                     1_cp36m    conda-forge
# pytz                      2018.9                   py36_0
# pywavelets                1.0.1            py36hdd07704_0
# pyyaml                    3.13             py36h14c3975_0
# pyzmq                     17.1.2           py36he6710b0_2
# qt                        5.9.7                h5867ecd_1
# qtawesome                 0.5.6                      py_0
# qtconsole                 4.4.3                    py36_0
# qtpy                      1.6.0                      py_0
# readline                  7.0                  h7b6447c_5
# requests                  2.21.0                   py36_0
# retrying                  1.3.3                      py_2
# rope                      0.11.0                     py_0
# ruamel_yaml               0.15.46          py36h14c3975_0
# s3transfer                0.1.13                   py36_0
# scikit-image              0.14.1           py36he6710b0_0
# scikit-learn              0.20.3           py36hd81dba3_0
# scipy                     1.2.0            py36h7c811a0_0
# seaborn                   0.9.0              pyh91ea838_1
# secretstorage             3.1.0                    py36_0
# send2trash                1.5.0                    py36_0
# setuptools                40.8.0                   py36_0
# simplegeneric             0.8.1                    py36_2
# singledispatch            3.4.0.3                  py36_0
# sip                       4.19.8           py36hf484d3e_0
# six                       1.12.0                   py36_0
# snappy                    1.1.7                hbae5bb6_3
# snowballstemmer           1.2.1                    py36_0
# sortedcollections         1.1.2                    py36_0
# sortedcontainers          2.1.0                    py36_0
# soupsieve                 1.7.1                    py36_0
# sphinx                    1.8.4                    py36_0
# sphinxcontrib             1.0                      py36_1
# sphinxcontrib-websupport  1.1.0                    py36_1
# spyder                    3.3.3                    py36_0
# spyder-kernels            0.4.2                    py36_0
# sqlalchemy                1.2.18           py36h7b6447c_0
# sqlite                    3.30.1               h7b6447c_0
# statsmodels               0.9.0            py36h035aef0_0
# streamsx                  1.13.14                   <pip>
# sympy                     1.3                      py36_0
# tabulate                  0.8.2                    py36_0
# tblib                     1.3.2                    py36_0
# tensorflow-base           1.13.1          mkl_py36h7ce6ba3_0
# tensorflow-estimator      1.13.0                     py_0
# termcolor                 1.1.0                    py36_1
# terminado                 0.8.1                    py36_1
# testpath                  0.4.2                    py36_0
# thrift-cpp                0.11.0               h02b749d_3
# tk                        8.6.8                hbc83047_0
# toolz                     0.9.0                    py36_0
# tornado                   5.1.1            py36h7b6447c_0
# tqdm                      4.31.1                   py36_1
# traitlets                 4.3.2                    py36_0
# typed-ast                 1.3.1            py36h7b6447c_0
# unicodecsv                0.14.1                   py36_0
# unixodbc                  2.3.7                h14c3975_0
# urllib3                   1.24.1                   py36_0
# vincent                   0.4.4                      py_1    conda-forge
# watson-machine-learning-client 1.0.376                   <pip>
# wcwidth                   0.1.7                    py36_0
# webencodings              0.5.1                    py36_1
# werkzeug                  0.14.1                   py36_0
# wheel                     0.32.3                   py36_0
# widgetsnbextension        3.4.2                    py36_0
# wrapt                     1.11.1           py36h7b6447c_0
# wurlitzer                 1.0.2                    py36_0
# xlrd                      1.2.0                      py_0
# xlsxwriter                1.1.2                    py36_0
# xlwt                      1.3.0                    py36_0
# xz                        5.2.4                h14c3975_4
# yaml                      0.1.7                had09818_2
# zeromq                    4.3.1                he6710b0_3
# zict                      0.1.3                    py36_0
# zlib                      1.2.11               h7b6447c_3
# zstd                      1.3.7                h0b5b093_0

# %%
neighborhood.head()
# Out:
#    Cluster Labels Postcode      Borough                         Neighbourhood  \
# 0               0      M1B  Scarborough                         Rouge,Malvern
# 1               0      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2               0      M1E  Scarborough       Guildwood,Morningside,West Hill
# 3               0      M1G  Scarborough                                Woburn
# 4               0      M1H  Scarborough                             Cedarbrae
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
neighborhood.insert(0, 'Cluster Labels', 0)

# %%
import folium
import numpy as np
from matplotlib import cm
from matplotlib import colors
map_clusters = folium.Map(neighborhood=['Latitude', 'Longitude'], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(neighborhood['Latitude'], neighborhood['Longitude'], neighborhood['Neighbourhood'], neighborhood['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-24615819b525> in <module>
#      13 # add markers to the map
#      14 markers_colors = []
# ---> 15 for lat, lon, poi, cluster in zip(neighborhood['Latitude'], neighborhood['Longitude'], neighborhood['Neighbourhood']):
#      16     label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
#      17     folium.CircleMarker(
#
# ValueError: not enough values to unpack (expected 4, got 3)
